# %% [markdown]
# # Лабораторная работа №2
# ## Выполнил студент группы ГРУППА ФИО

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)

# %% [markdown]
# ### Задание №1
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.

# %%
#генерация
import copy
import time
from random import randint

length=int(input('Длина: '))
min_value=int(input('Мин: '))
max_value=int(input('Макс: '))
randata=[]
for i in range(length):
    randata.append(randint(min_value,max_value))
print(randata)
#Бинарный поиск
def bin_search(randata, val):
    randata.sort()
    first = 0
    last = len(randata)-1
    index = -1
    while (first <= last) and (index == -1):
        mid = (first+last)//2
        if randata[mid] == val:
            index = mid
        else:
            if val<randata[mid]:
                last = mid -1
            else:
                first = mid +1
    return index
def bin_delete(randata, val):
    val_pos = bin_search(randata,val) 
    if val_pos != -1:
        randata.pop(val_pos)
        return True
    else:
        return False    
def bin_append(randata, val):
    if len(randata) == 1:
        if randata[0] < val:
            randata.append(val)
        else:
            randata.insert(0, val)
        return
    first=0
    last=len(randata)-1
    while (first<=last): 
        mid = (first+last)//2
        if randata[mid]<=val and randata[mid+1]>=val:
            randata.insert(mid+1,val)
            return randata
        else:
            if val<randata[mid]:
                last=mid-1
            else:
                first=mid+1
randata1=copy.deepcopy(randata)
start_time=time.time()
print(bin_search(randata1,15))
bin_search_time=round((time.time()-start_time)*1000)
randata1.sort()
print(randata1)
print(bin_delete(randata1,10))
print(bin_append(randata1,20))
print("--- {0} ms ---".format(bin_search_time))
# Out:
# [1, 48, 46, 12, 15, 31, 19, 19, 28, 34, 28, 46, 19, 20, 33, 38, 46, 47, 8, 40, 42, 29, 16, 17, 17, 10, 9, 34, 48, 28, 48, 38, 47, 8, 34, 10, 42, 9, 31, 2, 41, 21, 27, 27, 35, 45, 24, 33, 21, 45]
# 9
# [1, 2, 8, 8, 9, 9, 10, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# True
# [1, 2, 8, 8, 9, 9, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# --- 0 ms ---

# %%
#Бинарное дерево
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None
# Отсортированный (inorder) обход
def inorder(root):
    if root is not None:
        # Обходим левое поддерево
        inorder(root.left)
        # Обходим корень
        print(str(root.key) + "->", end=' ')
        # Обходим правое поддерево
        inorder(root.right)
# Вставка элемента
def insert(node, key):
    # Возвращаем новый узел, если дерево пустое
    if node is None:
        return Node(key)

    # Идем в нужное место и вставляет узел
    if key < node.key:
        node.left = insert(node.left, key)
    else:
        node.right = insert(node.right, key)
    return node
# Поиск inorder-преемника
def minValueNode(node):
    current = node
    # Найдем крайний левый лист — он и будет inorder-преемником
    while(current.left is not None):
        current = current.left
    return current
# Удаление узла
def deleteNode(root, key):
    # Возвращаем, если дерево пустое
    if root is None:
        return root
    # Найдем узел, который нужно удалить
    if key < root.key:
        root.left = deleteNode(root.left, key)
    elif(key > root.key):
        root.right = deleteNode(root.right, key)
    else:
        # Если у узла только один дочерний узел или вообще их нет        
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None
            return temp
        # Если у узла два дочерних узла,
        # помещаем центрированного преемника
        # на место узла, который нужно удалить
        temp = minValueNode(root.right)
        root.key = temp.key
        # Удаляем inorder-преемниа
        root.right = deleteNode(root.right, temp.key)
    return root
root = None
root = insert(root, 8)
root = insert(root, 3)
root = insert(root, 1)
root = insert(root, 6)
root = insert(root, 7)
root = insert(root, 10)
root = insert(root, 14)
root = insert(root, 4)
print("Начальное дерево: ", end=' ')
inorder(root)
print("\nПосле удаления 10")
root = deleteNode(root, 10)
print("Проверка: ", end=' ')
inorder(root)
print("\nПосле добавления 13")
root = insert(root, 13)
print("Проверка: ", end=' ')
inorder(root)
# Out:
# Начальное дерево:  1-> 3-> 4-> 6-> 7-> 8-> 10-> 14->
# После удаления 10
# Проверка:  1-> 3-> 4-> 6-> 7-> 8-> 14->
# После добавления 13
# Проверка:  1-> 3-> 4-> 6-> 7-> 8-> 13-> 14->

# %%
#Метод Фибоначчи
def fib_search(randata,val):
    randata.sort()
    size=len(randata)
    start=-1

    fib_num1=0
    fib_num2=1
    fib_sum=1
    while fib_sum<size:
        fib_num1=fib_num2
        fib_num2=fib_sum
        fib_sum=fib_num1+fib_num2
    while fib_sum>1:
        index = min(start+fib_num1, size -1)
        if randata[index]<val:
            fib_sum=fib_num2
            fib_num2=fib_num1
            fib_num1=fib_sum-fib_num2
            start=index
        elif randata[index]>val:
            fib_sum=fib_num1
            fib_num2=fib_num2-fib_num1
            fib_num1=fib_sum-fib_num2
        else:
            return index+1
    if fib_num2 and randata[size-1]==val:
        return size
    return None
def fib_delete(randata,val):
    i = fib_search(randata,val) 
    if i is not None:
        randata.pop(i-1)
    return randata
def fib_append(randata,val):
    randata.sort()
    size = len(randata)
    if randata[size-1]<=val:
        randata.append(val)
        return randata
    if randata[0]>=val: 
        randata.insert(0,val)
        return randata
    start = -1
    fib_num1 = 0
    fib_num2 = 1
    fib_sum = 1
    while fib_sum<size:
        fib_num1=fib_num2
        fib_num2=fib_sum
        fib_sum=fib_num1+fib_num2
    while fib_sum>1:
        index = min(start+fib_num1, size -1)
        if randata[index]<=val and randata[index+1]>=val:
            randata.insert(index+1,val)
            return randata
        elif randata[index]<val:
            fib_sum=fib_num2
            fib_num2=fib_num1
            fib_num1=fib_sum-fib_num2
            start=index
        else:
            fib_sum=fib_num1
            fib_num2=fib_num2-fib_num1
            fib_num1=fib_sum-fib_num2
randata2=copy.deepcopy(randata)
start_time=time.time()
print(fib_search(randata2,15))
fib_search_time=round((time.time() - start_time)*1000)
randata2.sort()
print(randata2)
print(fib_delete(randata2,10))
print(fib_append(randata2,5))
print("--- {0} ms ---".format(fib_search_time))
# Out:
# 10
# [1, 2, 8, 8, 9, 9, 10, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# [1, 2, 8, 8, 9, 9, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# [1, 2, 5, 8, 8, 9, 9, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# --- 0 ms ---

# %%
#Интерполяционный
def int_search(randata, val):
    randata.sort()
    low=0
    high=len(randata)-1
    while low<=high and val>=randata[low] and val<=randata[high]:
        index = low + int(((float(high-low)/(randata[high]-randata[low])) * (val-randata[low])))
        if randata[index]==val:
            return index+1
        if randata[index]<val:
            low=index+1
        else:
            high=index-1
    return None
def int_delete(randata,val):
    i = int_search(randata, val) 
    if i is not None:
        randata.pop(i-1)
    return randata
def int_append(randata, val):
    randata.sort()
    if randata[-1]<val:    
        randata.append(val)
        return randata
    if randata[0]>val:      
        randata.insert(0,val)
        return randata

    low=0
    high=len(randata)-1
    while low<=high and val>=randata[low] and val<=randata[high]:
        index = low + int(((float(high-low)/(randata[high]-randata[low])) * (val-randata[low])))
        if randata[index]<=val and randata[index+1]>=val:
            randata.insert(index+1,val)
            return randata
        elif randata[index]<val:
            low=index+1
        else:
            high=index-1
randata3=copy.deepcopy(randata)
start_time=time.time()
print(int_search(randata3,31))
int_search_time=round((time.time() - start_time)*1000)
randata3.sort()
print(randata3)
print(int_delete(randata3,8))
print(int_append(randata3,51))
print("--- {0} ms ---".format(int_search_time))
# Out:
# 28
# [1, 2, 8, 8, 9, 9, 10, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# [1, 2, 8, 9, 9, 10, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48]
# [1, 2, 8, 9, 9, 10, 10, 12, 15, 16, 17, 17, 19, 19, 19, 20, 21, 21, 24, 27, 27, 28, 28, 28, 29, 31, 31, 33, 33, 34, 34, 34, 35, 38, 38, 40, 41, 42, 42, 45, 45, 46, 46, 46, 47, 47, 48, 48, 48, 51]
# --- 0 ms ---

# %% [markdown]
# ### Задание №2
# Написать соответствующие решения для заданных методов.

# %%
#Простое рехэширование
data_list = ["Swain", "Xayah", "Aphelios", "Jhin", "Thresh", "Leona", "Diana"]

data_hash_list = [0 for i in range(len(data_list))]
def simple_hash(data, size, p = 0):
    sum = 0
    for data in data_list:
        sum += ord(element)
    return (sum + p) % size

for data in data_list:
    i = simple_hash(data, len(data_list))
    p = 1
    while data_hash_list[i] != 0:
        i = simple_hash(data, len(data_list), p)
        p += 1
    data_hash_list[i] = data

print(data_hash_list)
for data in data_list:
    i = simple_hash(data, len(data_list))
    p = 1
    while data_hash_list[i] != data:
        i = simple_hash(data, len(data_list), p)
        p += 1
    print(data_hash_list[i], i)

for data in data_list: #вывод для демонстрации кол-ва коллизий
    print(data, simple_hash(data, len(data_list)), data == data_hash_list[simple_hash(data, len(data_list))])
# Out:
# ['Swain', 'Xayah', 'Aphelios', 'Jhin', 'Thresh', 'Leona', 'Diana']
# Swain 0
# Xayah 1
# Aphelios 2
# Jhin 3
# Thresh 4
# Leona 5
# Diana 6
# Swain 0 True
# Xayah 0 False
# Aphelios 0 False
# Jhin 0 False
# Thresh 0 False
# Leona 0 False
# Diana 0 False

# %%
#Рехэширование с помощью псевдослучайных чисел
data_hash_list = [0 for i in range(len(data_list))]

def generate_random_num(data, size, p):
    a = 3
    b = 7
    return ((p ** b) // (size ** a)) + len(data) ** (b - a)

def random_hash(data, size, p = 0):
    result = 0
    for el in data:
        result += ord(el)
    return (result + generate_random_num(data, size, p)) % size

for data in data_list:
    i = random_hash(data, len(data_list))
    p = 1
    while data_hash_list[i] != 0:
        i = random_hash(data, len(data_list), p)
        p += 1
    data_hash_list[i] = data

print(data_hash_list)
#вывод имени и его позиции в списке
for data in data_list:
    i = random_hash(data, len(data_list))
    p = 1
    while data_hash_list[i] != data:
        i = random_hash(data, len(data_list), p)
        p += 1
    print(data_hash_list[i], i)

for data in data_list: #вывод для демонстрации кол-ва коллизий
    print(data, random_hash(data, len(data_list)), data == data_hash_list[random_hash(data, len(data_list))])
# Out:
# ['Thresh', 'Jhin', 'Diana', 'Aphelios', 'Xayah', 'Swain', 'Leona']
# Swain 5
# Xayah 4
# Aphelios 3
# Jhin 1
# Thresh 0
# Leona 6
# Diana 2
# Swain 5 True
# Xayah 5 False
# Aphelios 3 True
# Jhin 5 False
# Thresh 0 True
# Leona 0 False
# Diana 3 False

# %%
#Метод цепочек
class Node():
    
    def __init__(self, data = None):
        self.data = data
        self.next = None
    
    def add(self, data):
        if self.data is None:
            self.data = data
        elif self.next is None:
            self.next = Node(data)
        else:
            self.next.add(data)
    def print_Node(self):
        if self.data:
            print(self.data, end = ' ')
            if self.next:
                self.next.print_Node()
            else:
                return
data_hash_list = [Node() for i in range(len(data_list))]

def node_hash(data, size):
    result = 0
    for el in data:
        result += ord(el)
    return result % size

for data in data_list:
    i = node_hash(data, len(data_list))
    data_hash_list[i].add(data)

#печать получившегося списка
for i in range(len(data_hash_list)):
    print(i, end = ' ')
    data_hash_list[i].print_Node()
    print()
# Out:
# 0
# 1 Jhin Diana
# 2 Aphelios
# 3 Swain Xayah
# 4
# 5 Leona
# 6 Thresh

# %% [markdown]
# ### Задание №3
# Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки, расположенные по вертикалям, горизонталям и обеим диагоналям
# Написать программу,  которая находит хотя бы один способ решения задач.

# %%
queensnum=8
def print_board():
    print('===============')
    for x in range(queensnum):
        for y in range(queensnum):
            if x == board[y]:
                print('Q', end=' ')
            else:
                print('[]', end=' ')
        print('')
def attack(row, col, board):
    for i in range(col):
        offset_col = abs(i - col)
        offset_row = abs(board[i] - row)
        if board[i] == row or offset_row == offset_col:
            return True
    return False
def queens(board, value = 0):
    for i in range(queensnum):
        if not attack(i, value, board):
            board[value] = i
            if value == queensnum - 1:
                print_board()
            else:
                queens(board, value + 1)
board = [0] * queensnum
queens(board)
# Out:
# ...
# Q [] [] [] [] [] [] []
# [] [] [] [] [] [] Q []
# [] [] [] [] Q [] [] []
# [] [] [] [] [] [] [] Q
# [] Q [] [] [] [] [] []
# [] [] [] Q [] [] [] []
# [] [] [] [] [] Q [] []
# [] [] Q [] [] [] [] []
# ...
# Q [] [] [] [] [] [] []
# [] [] [] [] [] [] Q []
# [] [] [] Q [] [] [] []
# [] [] [] [] [] Q [] []
# [] [] [] [] [] [] [] Q
# [] Q [] [] [] [] [] []
# [] [] [] [] Q [] [] []
# [] [] Q [] [] [] [] []
# ...
# Q [] [] [] [] [] [] []
# [] [] [] [] [] Q [] []
# [] [] [] [] [] [] [] Q
# [] [] Q [] [] [] [] []
# [] [] [] [] [] [] Q []
# [] [] [] Q [] [] [] []
# [] Q [] [] [] [] [] []
# [] [] [] [] Q [] [] []
# ...
# Q [] [] [] [] [] [] []
# [] [] [] [] Q [] [] []
# [] [] [] [] [] [] [] Q
# [] [] [] [] [] Q [] []
# [] [] Q [] [] [] [] []
# [] [] [] [] [] [] Q []
# [] Q [] [] [] [] [] []
# [] [] [] Q [] [] [] []
# ...
# [] [] [] [] [] Q [] []
# Q [] [] [] [] [] [] []
# [] [] [] [] Q [] [] []
# [] Q [] [] [] [] [] []
# [] [] [] [] [] [] [] Q
# [] [] Q [] [] [] [] []
# [] [] [] [] [] [] Q []
# [] [] [] Q [] [] [] []
# ...
